# %%
import pandas as pd
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)
import numpy as np
import matplotlib.pyplot as plt  # 그래프 그리는 라이브러리
from sklearn.model_selection import train_test_split
from sklearn import metrics  # 평가를 위한 라이브러리
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import seaborn as sns  # 시각화 라이브러리
from sklearn.naive_bayes import GaussianNB # Naive Bayes classification model

# %%
# matplotlib 한글 출력 가능하도록 만들기
from matplotlib import font_manager, rc

# %%
train = pd.read_csv('/Users/daewonYoon/Desktop/Machine Learning/Project 3/data/data.csv', index_col = 'day_text')

# %% [markdown]
# ### 결측치 채우기

# %%
#결측치 확인
train.isnull().sum()
# Out:
# time_text         0
# team_text         0
# location          0
# H_text            0
# HR_text           0
# S_text            0
# ST_text           0
# DU_text           0
# ER_text           0
# result_text       0
# temp              0
# rain           7212
# wind              2
# d_wind            2
# humidity          0
# atmosphere        0
# surface           2
# dtype: int64

# %%
#결측치 0으로 채우기
train['rain'] = train['rain'].fillna('0')
train['wind'] = train['wind'].fillna('0')
train['d_wind'] = train['d_wind'].fillna('0')
train['surface'] = train['surface'].fillna('0')

# %%
train.isnull().sum()
# Out:
# time_text      0
# team_text      0
# location       0
# H_text         0
# HR_text        0
# S_text         0
# ST_text        0
# DU_text        0
# ER_text        0
# result_text    0
# temp           0
# rain           0
# wind           0
# d_wind         0
# humidity       0
# atmosphere     0
# surface        0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10230 entries, 4.2화 to 9.30일
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time_text    10230 non-null  object
#  1   team_text    10230 non-null  object
#  2   location     10230 non-null  object
#  3   H_text       10230 non-null  int64
#  4   HR_text      10230 non-null  int64
#  5   S_text       10230 non-null  int64
#  6   ST_text      10230 non-null  int64
#  7   DU_text      10230 non-null  int64
#  8   ER_text      10230 non-null  int64
#  9   result_text  10230 non-null  int64
#  10  temp         10230 non-null  float64
#  11  rain         10230 non-null  object
#  12  wind         10230 non-null  object
#  13  d_wind       10230 non-null  object
#  14  humidity     10230 non-null  int64
#  15  atmosphere   10230 non-null  float64
#  16  surface      10230 non-null  object
# dtypes: float64(2), int64(8), object(7)
# memory usage: 1.4+ MB

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = train.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
train['rain'] = train['rain'].astype('float64')
train['wind'] = train['wind'].astype('float64')
train['d_wind'] = train['d_wind'].astype('float64')
train['atmosphere'] = train['atmosphere'].astype('float64')
train['surface'] = train['surface'].astype('float64')

# %% [markdown]
# ### 원핫인코딩

# %%
cat_feature = ['team_text','location']

# %%
for i in cat_feature:
    dummy = pd.get_dummies(train[i], prefix = i)
    train = pd.concat([train, dummy], axis = 1)
    train.drop(i, axis=1, inplace = True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10230 entries, 4.2화 to 9.30일
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time_text           10230 non-null  object
#  1   H_text              10230 non-null  int64
#  2   HR_text             10230 non-null  int64
#  3   S_text              10230 non-null  int64
#  4   ST_text             10230 non-null  int64
#  5   DU_text             10230 non-null  int64
#  6   ER_text             10230 non-null  int64
#  7   result_text         10230 non-null  int64
#  8   temp                10230 non-null  float64
#  9   rain                10230 non-null  float64
#  10  wind                10230 non-null  float64
#  11  d_wind              10230 non-null  float64
#  12  humidity            10230 non-null  int64
#  13  atmosphere          10230 non-null  float64
#  14  surface             10230 non-null  float64
#  15  team_text_KIA 타이거즈  10230 non-null  uint8
#  16  team_text_LG 트윈스    10230 non-null  uint8
#  17  team_text_NC 다이노스   10230 non-null  uint8
#  18  team_text_SK 와이번스   10230 non-null  uint8
#  19  team_text_kt wiz    10230 non-null  uint8
#  20  team_text_두산 베어스    10230 non-null  uint8
#  21  team_text_롯데 자이언츠   10230 non-null  uint8
#  22  team_text_삼성 라이온즈   10230 non-null  uint8
#  23  team_text_키움 히어로즈   10230 non-null  uint8
#  24  team_text_한화 이글스    10230 non-null  uint8
#  25  location_광주         10230 non-null  uint8
#  26  location_대구         10230 non-null  uint8
#  27  location_대전         10230 non-null  uint8
#  28  location_부산         10230 non-null  uint8
#  29  location_서울         10230 non-null  uint8
#  30  location_수원         10230 non-null  uint8
#  31  location_인천         10230 non-null  uint8
#  32  location_창원         10230 non-null  uint8
# dtypes: float64(6), int64(8), object(1), uint8(18)
# memory usage: 1.4+ MB

# %% [markdown]
# ### 데이터 7:3으로 나누기

# %%
#7대 3으로 데이터 나누기
X = train.drop('DU_text',axis = 1)
y = train['DU_text']

X_train, X_test, y_train,y_test = train_test_split(X,y,
                                                  test_size = 0.3,
                                                  #stratify = y,
                                                  random_state = 3)

# %%
print(X_train.shape, y_train.shape,X_test.shape,y_test.shape)
# Out:
# (7161, 32) (7161,) (3069, 32) (3069,)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7161 entries, 9.5수 to 8.2일
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time_text           7161 non-null   object
#  1   H_text              7161 non-null   int64
#  2   HR_text             7161 non-null   int64
#  3   S_text              7161 non-null   int64
#  4   ST_text             7161 non-null   int64
#  5   ER_text             7161 non-null   int64
#  6   result_text         7161 non-null   int64
#  7   temp                7161 non-null   float64
#  8   rain                7161 non-null   float64
#  9   wind                7161 non-null   float64
#  10  d_wind              7161 non-null   float64
#  11  humidity            7161 non-null   int64
#  12  atmosphere          7161 non-null   float64
#  13  surface             7161 non-null   float64
#  14  team_text_KIA 타이거즈  7161 non-null   uint8
#  15  team_text_LG 트윈스    7161 non-null   uint8
#  16  team_text_NC 다이노스   7161 non-null   uint8
#  17  team_text_SK 와이번스   7161 non-null   uint8
#  18  team_text_kt wiz    7161 non-null   uint8
#  19  team_text_두산 베어스    7161 non-null   uint8
#  20  team_text_롯데 자이언츠   7161 non-null   uint8
#  21  team_text_삼성 라이온즈   7161 non-null   uint8
#  22  team_text_키움 히어로즈   7161 non-null   uint8
#  23  team_text_한화 이글스    7161 non-null   uint8
#  24  location_광주         7161 non-null   uint8
#  25  location_대구         7161 non-null   uint8
#  26  location_대전         7161 non-null   uint8
#  27  location_부산         7161 non-null   uint8
#  28  location_서울         7161 non-null   uint8
#  29  location_수원         7161 non-null   uint8
#  30  location_인천         7161 non-null   uint8
#  31  location_창원         7161 non-null   uint8
# dtypes: float64(6), int64(7), object(1), uint8(18)
# memory usage: 965.1+ KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3069 entries, 9.1일 to 5.13일
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time_text           3069 non-null   object
#  1   H_text              3069 non-null   int64
#  2   HR_text             3069 non-null   int64
#  3   S_text              3069 non-null   int64
#  4   ST_text             3069 non-null   int64
#  5   ER_text             3069 non-null   int64
#  6   result_text         3069 non-null   int64
#  7   temp                3069 non-null   float64
#  8   rain                3069 non-null   float64
#  9   wind                3069 non-null   float64
#  10  d_wind              3069 non-null   float64
#  11  humidity            3069 non-null   int64
#  12  atmosphere          3069 non-null   float64
#  13  surface             3069 non-null   float64
#  14  team_text_KIA 타이거즈  3069 non-null   uint8
#  15  team_text_LG 트윈스    3069 non-null   uint8
#  16  team_text_NC 다이노스   3069 non-null   uint8
#  17  team_text_SK 와이번스   3069 non-null   uint8
#  18  team_text_kt wiz    3069 non-null   uint8
#  19  team_text_두산 베어스    3069 non-null   uint8
#  20  team_text_롯데 자이언츠   3069 non-null   uint8
#  21  team_text_삼성 라이온즈   3069 non-null   uint8
#  22  team_text_키움 히어로즈   3069 non-null   uint8
#  23  team_text_한화 이글스    3069 non-null   uint8
#  24  location_광주         3069 non-null   uint8
#  25  location_대구         3069 non-null   uint8
#  26  location_대전         3069 non-null   uint8
#  27  location_부산         3069 non-null   uint8
#  28  location_서울         3069 non-null   uint8
#  29  location_수원         3069 non-null   uint8
#  30  location_인천         3069 non-null   uint8
#  31  location_창원         3069 non-null   uint8
# dtypes: float64(6), int64(7), object(1), uint8(18)
# memory usage: 413.6+ KB

# %% [markdown]
# ### Time_text Drop

# %%
X_train.drop('time_text', axis = 1 , inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
X_test.drop('time_text', axis = 1, inplace = True)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3069 entries, 9.1일 to 5.13일
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   H_text              3069 non-null   int64
#  1   HR_text             3069 non-null   int64
#  2   S_text              3069 non-null   int64
#  3   ST_text             3069 non-null   int64
#  4   ER_text             3069 non-null   int64
#  5   result_text         3069 non-null   int64
#  6   temp                3069 non-null   float64
#  7   rain                3069 non-null   float64
#  8   wind                3069 non-null   float64
#  9   d_wind              3069 non-null   float64
#  10  humidity            3069 non-null   int64
#  11  atmosphere          3069 non-null   float64
#  12  surface             3069 non-null   float64
#  13  team_text_KIA 타이거즈  3069 non-null   uint8
#  14  team_text_LG 트윈스    3069 non-null   uint8
#  15  team_text_NC 다이노스   3069 non-null   uint8
#  16  team_text_SK 와이번스   3069 non-null   uint8
#  17  team_text_kt wiz    3069 non-null   uint8
#  18  team_text_두산 베어스    3069 non-null   uint8
#  19  team_text_롯데 자이언츠   3069 non-null   uint8
#  20  team_text_삼성 라이온즈   3069 non-null   uint8
#  21  team_text_키움 히어로즈   3069 non-null   uint8
#  22  team_text_한화 이글스    3069 non-null   uint8
#  23  location_광주         3069 non-null   uint8
#  24  location_대구         3069 non-null   uint8
#  25  location_대전         3069 non-null   uint8
#  26  location_부산         3069 non-null   uint8
#  27  location_서울         3069 non-null   uint8
#  28  location_수원         3069 non-null   uint8
#  29  location_인천         3069 non-null   uint8
#  30  location_창원         3069 non-null   uint8
# dtypes: float64(6), int64(7), uint8(18)
# memory usage: 389.6+ KB

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7161 entries, 9.5수 to 8.2일
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   H_text              7161 non-null   int64
#  1   HR_text             7161 non-null   int64
#  2   S_text              7161 non-null   int64
#  3   ST_text             7161 non-null   int64
#  4   ER_text             7161 non-null   int64
#  5   result_text         7161 non-null   int64
#  6   temp                7161 non-null   float64
#  7   rain                7161 non-null   float64
#  8   wind                7161 non-null   float64
#  9   d_wind              7161 non-null   float64
#  10  humidity            7161 non-null   int64
#  11  atmosphere          7161 non-null   float64
#  12  surface             7161 non-null   float64
#  13  team_text_KIA 타이거즈  7161 non-null   uint8
#  14  team_text_LG 트윈스    7161 non-null   uint8
#  15  team_text_NC 다이노스   7161 non-null   uint8
#  16  team_text_SK 와이번스   7161 non-null   uint8
#  17  team_text_kt wiz    7161 non-null   uint8
#  18  team_text_두산 베어스    7161 non-null   uint8
#  19  team_text_롯데 자이언츠   7161 non-null   uint8
#  20  team_text_삼성 라이온즈   7161 non-null   uint8
#  21  team_text_키움 히어로즈   7161 non-null   uint8
#  22  team_text_한화 이글스    7161 non-null   uint8
#  23  location_광주         7161 non-null   uint8
#  24  location_대구         7161 non-null   uint8
#  25  location_대전         7161 non-null   uint8
#  26  location_부산         7161 non-null   uint8
#  27  location_서울         7161 non-null   uint8
#  28  location_수원         7161 non-null   uint8
#  29  location_인천         7161 non-null   uint8
#  30  location_창원         7161 non-null   uint8
# dtypes: float64(6), int64(7), uint8(18)
# memory usage: 909.1+ KB

# %%
set(X_train.columns) - set(X_test.columns)
# Out:
# set()

# %% [markdown]
# ### KNNRegressor

# %%
knn_model = KNeighborsRegressor(n_neighbors = 3)
result1 = cross_val_score(knn_model,
                        X_train,
                        y_train,
                        cv = 5)
result1
# Out:
# array([-0.27995951, -0.28450151, -0.37363002, -0.38685735, -0.2443719 ])

# %%
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
print("테스트 세트 예측: {}".format(knn_model.predict(X_test)))
# Out:
# 테스트 세트 예측: [1.         0.         0.33333333 ... 1.66666667 0.66666667 1.        ]

# %%
print("테스트 세트 정확도: {:.2f}".format(knn_model.score(X_test, y_test)))
# Out:
# 테스트 세트 정확도: -0.27

# %%
training_accuracy = []
test_accuracy = []
# 1에서 10까지 n_neighbors를 적용
neighbors_settings = range(1, 50)

for n_neighbors in neighbors_settings:
    # 모델 생성
    knn_model = KNeighborsRegressor(n_neighbors=n_neighbors)
    knn_model.fit(X_train, y_train)
    # 훈련 세트 정확도 저장
    training_accuracy.append(knn_model.score(X_train, y_train))
    # 일반화 정확도 저장
    test_accuracy.append(knn_model.score(X_test, y_test))

plt.plot(neighbors_settings, training_accuracy, label="train accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("accuracy")
plt.xlabel("n_neighbors")
plt.legend()

# if there would be huge gap between train and test data, then you should reset neighbors_settings = range(1, 50)

# %%
train.corr()

# %% [markdown]
# # Decision Tree model

# %%
tree_model = DecisionTreeClassifier(max_depth = 7)

# %%
result = cross_val_score(tree_model,
                        X_train,
                        y_train,
                        cv = 10)
result
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# array([0.41283124, 0.43994413, 0.42458101, 0.43575419, 0.43296089,
#        0.42458101, 0.44413408, 0.42458101, 0.40363128, 0.41340782])

# %%
result.mean()
# Out:
# 0.42564066602775374

# %%
y_pred = tree_model.fit(X_train, y_train).predict(X_test)

# %%
print("총 DU 갯수 %d 에서 틀린 예측 갯수 : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 총 DU 갯수 3069 에서 틀린 예측 갯수 : 1774

# %%
print("예측 정확도: {:.2f}".format(np.mean(y_pred == y_test)))
# Out:
# 예측 정확도: 0.42

# %%
tree_model.score(X_test,y_test)
# Out:
# 0.42196155099380905

# %%
tree_model.score(X_train,y_train)
# Out:
# 0.4999301773495322

# %% [markdown]
# # KNN Scaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)  # 평균과 표준편차로 scaling 한 값을 컴퓨터가 기억
# Out:
# StandardScaler()

# %%
transform_X_train = scaler.transform(X_train)
transform_X_train
# Out:
# array([[-2.01738565,  0.08763645, -0.7591698 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        [-0.94931189, -0.87636449,  0.2498159 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        [-0.14825657,  2.01563833,  0.2498159 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        ...,
#        [-0.68229345,  0.08763645, -0.7591698 , ..., -0.28127198,
#          2.85814872, -0.31862649],
#        [-2.01738565, -0.87636449, -0.7591698 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        [-0.41527501,  0.08763645, -0.7591698 , ..., -0.28127198,
#         -0.34987683, -0.31862649]])

# %%
transform_X_test = scaler.transform(X_test)
transform_X_test
# Out:
# array([[-0.94931189, -0.87636449, -0.7591698 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        [-0.94931189,  0.08763645, -0.7591698 , ...,  3.55527777,
#         -0.34987683, -0.31862649],
#        [-0.68229345,  0.08763645,  0.2498159 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        ...,
#        [ 0.38578031,  0.08763645, -0.7591698 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        [ 0.11876187, -0.87636449, -0.7591698 , ..., -0.28127198,
#         -0.34987683, -0.31862649],
#        [-0.94931189,  1.05163739,  0.2498159 , ..., -0.28127198,
#         -0.34987683, -0.31862649]])

# %%
result = cross_val_score(knn_model,
                        transform_X_train,
                        y_train,
                        cv = 10)
result
# Out:
# array([-0.20341742, -0.24633476, -0.27610156, -0.24006829, -0.36819135,
#        -0.1899826 , -0.30495995, -0.33094515, -0.26911136, -0.23670939])

# %%
result = cross_val_score(knn_model,
                        transform_X_train,
                        y_train,
                        cv = 10)
result
# Out:
# array([-0.20341742, -0.24633476, -0.27610156, -0.24006829, -0.36819135,
#        -0.1899826 , -0.30495995, -0.33094515, -0.26911136, -0.23670939])

# %%
y_pred = knn_model.fit(transform_X_train, y_train).predict(transform_X_test)

# %%
print("총 DU  갯수 %d 에서 틀린 예측 갯수 : %d" % (transform_X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 총 DU  갯수 3069 에서 틀린 예측 갯수 : 2662

# %%
print("예측 정확도: {:.2f}".format(np.mean(y_pred == y_test)))
# Out:
# 예측 정확도: 0.13

# %% [markdown]
# # Naive Bayes model

# %%
nb = GaussianNB()

# %%
y_pred = nb.fit(X_train, y_train).predict(X_test)

# %%
print("총 DU 갯수 %d 에서 틀린 예측 갯수 : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# 총 DU 갯수 3069 에서 틀린 예측 갯수 : 2323

# %%
print("예측 정확도: {:.2f}".format(np.mean(y_pred == y_test)))
# Out:
# 예측 정확도: 0.24
